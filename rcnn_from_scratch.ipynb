# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow==2.0.0-beta0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0.0-beta0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0)
# ERROR: No matching distribution found for tensorflow==2.0.0-beta0

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %%
import os, cv2, keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
# !unzip "/content/drive/MyDrive/Airplanes_Annotations.zip" -d "/content/drive/MyDrive/annotations_rcnn"
# !unzip "/content/drive/MyDrive/Airplanes_Images.zip" -d "/content/drive/MyDrive/images_rcnn"
# Out:
# Archive:  /content/drive/MyDrive/Airplanes_Annotations.zip
# replace /content/drive/MyDrive/annotations_rcnn/Airplanes_Annotations/airplane_095.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: unzip:  cannot find or open /content/drive/MyDrive/Airplanes_Images.zip, /content/drive/MyDrive/Airplanes_Images.zip.zip or /content/drive/MyDrive/Airplanes_Images.zip.ZIP.

# %%
path = "/content/drive/MyDrive/images_rcnn/Images"
annot = "/content/drive/MyDrive/annotations_rcnn/Airplanes_Annotations"

# %%
index = 41
filename = "airplane_0"+str(index)+".jpg"
print(filename)
# Out:
# airplane_041.jpg

# %%
# Check if the file exists
if os.path.exists(os.path.join(path, filename)):
  img = cv2.imread(os.path.join(path, filename))

  # Check if the image was loaded correctly
  if img is not None:
    plt.imshow(img)
  else:
    print(f"Failed to load image: {filename}")
else:
  print(f"Image file not found: {filename}")

# %%
df = pd.read_csv(os.path.join(annot, filename.replace(".jpg", ".csv")))
print(df)
# Out:
#                 3
# 0     1 92 71 177
# 1   84 74 158 162
# 2  184 61 253 142

# %%
print(df.iterrows())
# Out:
# <generator object DataFrame.iterrows at 0x7f3284433d80>

# %%
for row in df.iterrows():
  x1 = int(row[1][0].split(" ")[0])
  y1 = int(row[1][0].split(" ")[1])
  x2 = int(row[1][0].split(" ")[2])
  y2 = int(row[1][0].split(" ")[3])
  cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), 2)
plt.figure()
plt.imshow(img)
# Out:
# <ipython-input-11-989be0b0c3a9>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x1 = int(row[1][0].split(" ")[0])
# <ipython-input-11-989be0b0c3a9>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y1 = int(row[1][0].split(" ")[1])
# <ipython-input-11-989be0b0c3a9>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x2 = int(row[1][0].split(" ")[2])
# ...

# %%
cv2.setUseOptimized(True)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
im = cv2.imread(os.path.join(path, "428461.jpg"))
ss.setBaseImage(im)
ss.switchToSelectiveSearchFast()
rects = ss.process()
imOut = im.copy()
for i, rect in (enumerate(rects)):
  x, y, w, h = rect
  #print(x, y, w, h)
  #imOut = imOut[x:x+w, y:y+h]
  #print(imOut)
  cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
  plt.figure()
plt.imshow(imOut)
# Out:
# <ipython-input-13-62ca675c72c1>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()

# %%
def get_iou(bb1, bb2):
  assert bb1['x1'] < bb1['x2']
  assert bb1['y1'] < bb1['y2']
  assert bb2['x1'] < bb2['x2']
  assert bb2['y1'] < bb2['y2']
  x_left = max(bb1['x1'], bb2['x1'])
  y_top = max(bb1['y1'], bb2['y1'])
  x_right = min(bb1['x2'], bb2['x2'])
  y_bottom = min(bb1['y2'], bb2['y2'])
  if x_right < x_left or y_bottom < y_top:
    return 0.0
  intersection_area = (x_right - x_left)*(y_bottom - y_top)
  bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
  bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
  iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
  assert iou >= 0.0
  assert iou <= 1.1
  return iou

# %%
os.listdir(annot)
# Out:
# ['airplane_262.csv',
#  '428501.csv',
#  'Planes7.csv',
#  'airplane_116.csv',
#  'airplane_225.csv',
#  'hotanairport5-rgb.csv',
#  'airplane_079.csv',
#  'airplane_207.csv',
#  '42845.csv',
#  'airplane_057.csv',
#  'airplane_143.csv',
#  'airplane_162.csv',
#  'airplane_107.csv',
#  'airplane_245.csv',
#  'Planes4.csv',
#  'airplane_307.csv',
#  'airplane_216.csv',
#  'airplane_086.csv',
#  'airplane_178.csv',
#  'airplane_309.csv',
#  'airplane_015.csv',
#  'airplane_125.csv',
#  'Planes11.csv',
#  'airplane_237.csv',
#  '428481.csv',
#  'airplane_047.csv',
#  'airplane_101.csv',
#  'airplane_205.csv',
#  'airplane_096.csv',
#  'airplane_230.csv',
#  'airplane_168.csv',
#  'airplane_121.csv',
#  'airplane_023.csv',
#  'airplane_184.csv',
#  '42850.csv',
#  'airplane_182.csv',
#  'airplane_284.csv',
#  'airplane_165.csv',
#  '42847.csv',
#  'airplane_274.csv',
#  'airplane_033.csv',
#  'airplane_263.csv',
#  'airplane_197.csv',
#  'airplane_179.csv',
#  'airplane_285.csv',
# ...

# %%
train_images = []
train_labels = []

for e, i in enumerate(os.listdir(annot)):
  try:
    if i.startswith('airplane'):
      filename = i.split(".")[0] + ".jpg"
      #print(e, filename)
      image = cv2.imread(os.path.join(path, filename))
      df = pd.read_csv(os.path.join(annot, i))
      gtvalues = []
      for row in df.iterrows():
        x1 = int(row[1][0].split(" ")[0])
        y1 = int(row[1][0].split(" ")[1])
        x2 = int(row[1][0].split(" ")[2])
        y2 = int(row[1][0].split(" ")[3])
        gtvalues.append({"x1": x1, "x2": x2, "y1": y1, "y2": y2})
      ss.setBaseImage(image)
      ss.switchToSelectiveSearchFast()
      ssresults = ss.process()
      imout = image.copy()
      counter = 0
      falsecounter = 0
      flag = 0
      fflag = 0
      bflag = 0
      for e, result in enumerate(ssresults):
        if e < 2000 and flag == 0:
          for gtval in gtvalues:
            x, y, w, h = result
            iou = get_iou(gtval, {"x1":x, "x2":x+w, "y1":y, "y2":y+h})
            if counter < 30:
              if iou > 0.70:
                timage = imout[x:x+w, y:y+h]
                resized = cv2.resize(timage, (224, 224), interpolation=cv2.INTER_AREA)
                train_images.append(resized)
                train_labels.append(1)
                counter += 1
              else:
                fflag = 1
            if falsecounter < 30:
              if iou < 0.3:
                timage = imout[x:x+w, y:y+h]
                resized = cv2.resize(timage, (224, 224), interpolation=cv2.INTER_AREA)
                train_images.append(resized)
                train_labels.append(0)
                falsecounter += 1
            else:
              bflag = 1
          if fflag == 1 and bflag == 1:
            print("inside")
            flag = 1
  except Exception as e:
    print(e)
    print("error in"+filename)
    continue
# Out:
# <ipython-input-20-c03370a5931f>:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x1 = int(row[1][0].split(" ")[0])
# <ipython-input-20-c03370a5931f>:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y1 = int(row[1][0].split(" ")[1])
# <ipython-input-20-c03370a5931f>:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   x2 = int(row[1][0].split(" ")[2])
# ...

# %%
print(len(train_images))
print(len(train_labels))
# Out:
# 1611
# 1611

# %%
train_images[0]
# Out:
# array([[[183, 178, 175],
#         [183, 178, 175],
#         [183, 178, 175],
#         ...,
#         [139, 158, 165],
#         [139, 158, 165],
#         [139, 158, 165]],
#
#        [[183, 178, 175],
#         [183, 178, 175],
#         [183, 178, 175],
#         ...,
#         [139, 158, 165],
#         [139, 158, 165],
#         [139, 158, 165]],
#
#        [[184, 179, 176],
#         [184, 179, 176],
#         [184, 179, 176],
#         ...,
#         [141, 160, 167],
#         [141, 160, 167],
#         [141, 160, 167]],
#
#        ...,
#
#        [[ 70,  84,  91],
#         [ 70,  84,  91],
#         [ 70,  84,  91],
#         ...,
#         [141, 150, 154],
#         [141, 150, 154],
#         [141, 150, 154]],
#
#        [[ 82,  96, 102],
#         [ 82,  96, 102],
#         [ 82,  96, 102],
#         ...,
#         [144, 151, 154],
#         [144, 151, 154],
#         [144, 151, 154]],
#
#        [[ 82,  96, 102],
#         [ 82,  96, 102],
#         [ 82,  96, 102],
# ...

# %%
X_new = np.array(train_images)
Y_new = np.array(train_labels)

# %%
X_new[1]
# Out:
# array([[[128, 137, 141],
#         [128, 137, 141],
#         [128, 137, 140],
#         ...,
#         [127, 140, 142],
#         [132, 145, 147],
#         [134, 148, 150]],
#
#        [[131, 140, 144],
#         [132, 141, 144],
#         [134, 143, 146],
#         ...,
#         [127, 140, 142],
#         [130, 143, 145],
#         [132, 145, 147]],
#
#        [[131, 140, 144],
#         [131, 140, 144],
#         [133, 142, 145],
#         ...,
#         [135, 148, 150],
#         [137, 150, 152],
#         [139, 152, 154]],
#
#        ...,
#
#        [[ 65,  70,  73],
#         [ 63,  68,  71],
#         [ 59,  65,  68],
#         ...,
#         [ 39,  58,  43],
#         [ 36,  55,  40],
#         [ 35,  54,  39]],
#
#        [[ 65,  70,  73],
#         [ 64,  70,  73],
#         [ 63,  70,  73],
#         ...,
#         [ 39,  58,  41],
#         [ 37,  56,  39],
#         [ 36,  55,  39]],
#
#        [[ 66,  73,  76],
#         [ 66,  73,  76],
#         [ 68,  75,  78],
# ...

# %%
from keras.layers import Dense
from keras import Model
from keras import optimizers

# %%
vgg = tf.keras.applications.vgg16.VGG16(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
for layer in vgg.layers[:-2]:
  layer.trainable = False
x = vgg.get_layer('fc2')
last_output = x.output
x = tf.keras.layers.Dense(1, activation='sigmoid')(last_output)
model = tf.keras.Model(vgg.input, x)
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['acc'])
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
model.summary()
model.fit(X_new,Y_new,batch_size = 64,epochs = 3, verbose = 1,validation_split=.05,shuffle = True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
svm_image = []
svm_label = []

# %%
for e,i in enumerate(os.listdir(annot)):
    try:
        if i.startswith("airplane"):
            filename = i.split(".")[0]+".jpg"
            print(e,filename)
            image = cv2.imread(os.path.join(path,filename))
            df = pd.read_csv(os.path.join(annot,i))
            gtvalues=[]
            for row in df.iterrows():
                x1 = int(row[1][0].split(" ")[0])
                y1 = int(row[1][0].split(" ")[1])
                x2 = int(row[1][0].split(" ")[2])
                y2 = int(row[1][0].split(" ")[3])
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
                timage = image[x1:x2,y1:y2]
                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                svm_image.append(resized)
                svm_label.append([0,1])
            ss.setBaseImage(image)
            ss.switchToSelectiveSearchFast()
            ssresults = ss.process()
            imout = image.copy()
            counter = 0
            falsecounter = 0
            flag = 0
            for e,result in enumerate(ssresults):
                if e < 2000 and flag == 0:
                    for gtval in gtvalues:
                        x,y,w,h = result
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                        if falsecounter <5:
                            if iou < 0.3:
                                timage = imout[x:x+w,y:y+h]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                svm_image.append(resized)
                                svm_label.append([1,0])
                                falsecounter += 1
                        else :
                            flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue
# Out:
# 0 airplane_262.jpg
# 'NoneType' object is not subscriptable
# error in airplane_262.jpg
# 3 airplane_116.jpg
# 'NoneType' object is not subscriptable
# error in airplane_116.jpg
# 4 airplane_225.jpg
# 'NoneType' object is not subscriptable
# error in airplane_225.jpg
# 6 airplane_079.jpg
# 'NoneType' object is not subscriptable
# error in airplane_079.jpg
# 7 airplane_207.jpg
# 'NoneType' object is not subscriptable
# error in airplane_207.jpg
# 9 airplane_057.jpg
# 'NoneType' object is not subscriptable
# error in airplane_057.jpg
# 10 airplane_143.jpg
# 'NoneType' object is not subscriptable
# error in airplane_143.jpg
# 11 airplane_162.jpg
# 'NoneType' object is not subscriptable
# error in airplane_162.jpg
# 12 airplane_107.jpg
# 'NoneType' object is not subscriptable
# error in airplane_107.jpg
# 13 airplane_245.jpg
# ...

# %%
model.save('my_model.h5')
model.save_weights('my_model_weights.weights.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
#adding svm to last layer
x =model.get_layer('fc2').output
# Change the number of units in the Dense layer to 1 to match the saved weights
Y = tf.keras.layers.Dense(1)(x)
final_model = tf.keras.Model(model.input,Y)
final_model.compile(loss='hinge',
              optimizer='adam',
              metrics=['accuracy'])
final_model.summary()
final_model.load_weights('my_model_weights.weights.h5')
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
hist_final = final_model.fit(np.array(svm_image),np.array(svm_label),batch_size=32,epochs = 2,verbose = 1,shuffle = True,validation_split = 0.05)
# Out:
# Epoch 1/2
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 266s 20s/step - accuracy: 0.5000 - loss: 1.4220 - val_accuracy: 0.5000 - val_loss: 1.0053
# Epoch 2/2
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 320s 20s/step - accuracy: 0.5000 - loss: 1.2261 - val_accuracy: 0.5000 - val_loss: 1.2010

# %%
import matplotlib.pyplot as plt
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist_final.history['loss'])
plt.plot(hist_final.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

# %%
image = cv2.imread(os.path.join(path,'airplane_020.jpg'))
ss.setBaseImage(image)
ss.switchToSelectiveSearchFast()
ssresults = ss.process()

imOut = image.copy()
boxes = []
count = 0
for e,result in enumerate(ssresults):
  if e < 50:
    x,y,w,h = result
    timage = imout[x:x+w,y:y+h]
    resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
    resized = np.expand_dims(resized,axis = 0)
    out = final_model.predict(resized)
    print(e,out)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 0 [[-1.2079176]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1 [[-0.84670144]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 2 [[-1.1955607]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step
# 3 [[-0.29002282]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 4 [[-1.2378037]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step
# 5 [[0.41176307]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 6 [[-0.91353]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 7 [[-0.54807484]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 8 [[-0.34772393]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 9 [[-0.22297719]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 10 [[-1.6799953]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 11 [[-1.6216532]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# 12 [[-1.6363939]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# 13 [[-0.5456221]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 14 [[-1.3344852]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# 15 [[-1.304275]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# ...

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Load image
image = cv2.imread(os.path.join(path, 'airplane_020.jpg'))

# Initialize Selective Search
ss.setBaseImage(image)
ss.switchToSelectiveSearchFast()
ssresults = ss.process()

# Copy the image for drawing
imOut = image.copy()

# Loop through the first 50 selective search results
for e, result in enumerate(ssresults):
    if e < 50:
        x, y, w, h = result

        # Extract region proposal from the image
        timage = imOut[y:y+h, x:x+w]  # Note the correct indexing for image slicing

        # Resize the region to the model input size
        resized = cv2.resize(timage, (224, 224), interpolation=cv2.INTER_AREA)

        # Expand dimensions to make it compatible with the model input
        resized = np.expand_dims(resized, axis=0)

        # Make prediction
        out = final_model.predict(resized)

        # Draw the rectangle on the image for visualization
        cv2.rectangle(imOut, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # You can optionally label the prediction on the image
        label = f"Prediction: {out}"
        cv2.putText(imOut, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the final image with bounding boxes
cv2_imshow(imOut)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 968ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# ...
